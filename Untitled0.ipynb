# %%
import os
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
directory = "/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/"

print(os.listdir(directory))
csv_files = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.csv')]

print(csv_files)
# Out:
# ['quarles20210526b_filtered.csv', '199710143_filtered.csv', 'brainard20220907a_filtered.csv', '19970424_filtered.csv', 'brainard20210302a_filtered.csv', '19980316_filtered.csv', 'waller20220506a_filtered.csv', 'waller20220224a_filtered.csv', '20011205_filtered.csv', '20021219_filtered.csv', '20000113_filtered.csv', '19990513_filtered.csv', '19991102_filtered.csv', '20041202_filtered.csv', 'fischer20170303a_filtered.csv', '20021122_filtered.csv', '20040604_filtered.csv', '20030203_filtered.csv', '200501072_filtered.csv', 'bernanke20070302a_filtered.csv', '19980108_filtered.csv', 'waller20220530a_filtered.csv', '19970912_filtered.csv', '20030924_filtered.csv', '19961016_filtered.csv', '20040225_filtered.csv', 'bernanke20060320a_filtered.csv', '20021015_filtered.csv', 'stein20130628a_filtered.csv', '19990610_filtered.csv', '20050520_filtered.csv', '20040505_filtered.csv', 'clarida20210804a_filtered.csv', '20030104_filtered.csv', 'clarida20210512a_filtered.csv', 'bies20060118a_filtered.csv', 'kohn20080105a_filtered.csv', '20050330_filtered.csv', 'bernanke20070831a_filtered.csv', '20051011_filtered.csv', 'bowman20220623a_filtered.csv', 'powell20170107a_filtered.csv', 'clarida20211012a_filtered.csv', 'kroszner20070309a_filtered.csv', '19990921_filtered.csv', 'clarida20210108a_filtered.csv', 'kohn20060316a_filtered.csv', 'brainard20191126a_filtered.csv', '20050526_filtered.csv', 'bowman20220806a_filtered.csv', '199709122_filtered.csv', '20040916_filtered.csv', 'bowman20221012a_filtered.csv', 'kroszner20061116a_filtered.csv', '20010717_filtered.csv', '20050527_filtered.csv', 'brainard20210113a_filtered.csv', 'quarles20200206a_filtered.csv', '20050211_filtered.csv', '19971202_filtered.csv', '20030531_filtered.csv', '20040103_filtered.csv', 'mishkin20071020a_filtered.csv', '19980116_filtered.csv', 'clarida20201014a_filtered.csv', '199910282_filtered.csv', '20001024_filtered.csv', '200410073_filtered.csv', 'clarida20200521a_filtered.csv', '20021024_filtered.csv', 'brainard20221010a_filtered.csv', '20011012_filtered.csv', '19970905_filtered.csv', 'bowman20211013a_filtered.csv', 'waller20210513a_filtered.csv', '20030829_filtered.csv', 'mishkin20071105a_filtered.csv', 'clarida20200225a_filtered.csv', '20010220_filtered.csv', '20030522_filtered.csv', 'brainard20170117a_filtered.csv', 'brainard20210224a_filtered.csv', 'kroszner20070312a_filtered.csv', 'yellen20170118a_filtered.csv', 'kroszner20060927a_filtered.csv', '200105212_filtered.csv', 'brainard20200901a_filtered.csv', 'bernanke20060831a_filtered.csv', 'brainard20220930a_filtered.csv', '20050420_filtered.csv', 'kohn20061201a_filtered.csv', 'clarida20191112a_filtered.csv', '20001208_filtered.csv', 'powell20220321a_filtered.csv', '20000606_filtered.csv', '200404232_filtered.csv', 'mishkin20070927a_filtered.csv', '20030324_filtered.csv', '19980409_filtered.csv', 'powell20200827a_filtered.csv', '20030212_filtered.csv', '20021023_filtered.csv', '20040624_filtered.csv', '19980709_filtered.csv', 'brainard20220405a_filtered.csv', 'mishkin20070410a_filtered.csv', '20040707_filtered.csv', '20050119_filtered.csv', 'clarida20211119a_filtered.csv', '20031002_filtered.csv', '20011130_filtered.csv', '19991012_filtered.csv', '200404012_filtered.csv', '19970508_filtered.csv', '19990827_filtered.csv', '200410072_filtered.csv', '200401033_filtered.csv', 'waller20220714a_filtered.csv', 'bowman20210505a_filtered.csv', 'clarida20201019a_filtered.csv', 'kroszner20070516a_filtered.csv', 'warsh20060718a_filtered.csv', 'kohn20070309a_filtered.csv', 'clarida20200831a_filtered.csv', 'clarida20210325a_filtered.csv', '20050112_filtered.csv', 'bernanke20060605a_filtered.csv', 'mishkin20070323a_filtered.csv', '20010614_filtered.csv', '20040415_filtered.csv', '20000412_filtered.csv', '20051114_filtered.csv', '200503102_filtered.csv', 'powell20191008a_filtered.csv', '19971107_filtered.csv', 'waller20211019a_filtered.csv', 'brainard20200714a_filtered.csv', '20050207_filtered.csv', 'brainard20200221a_filtered.csv', '20051 ...
# ['/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/quarles20210526b_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/199710143_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/brainard20220907a_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/19970424_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/brainard20210302a_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/19980316_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/waller20220506a_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/waller20220224a_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/20011205_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/20021219_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/20000113_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/19990513_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/19991102_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/20041202_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/fischer20170303a_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/20021122_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/20040604_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/20030203_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200501072_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/bernanke20070302a_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/19980108_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/waller20220530a_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/19970912_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/20030924_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/19961016_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/20040225_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/bernanke20060320a_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/20021015_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/stein20130628a_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/19990610_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/20050520_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/20040505_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/clarida20210804a_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/20030104_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/clarida20210512a_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/bies20060118a_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/kohn20080105a_filtered.csv', '/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/20 ...

# %%
import re
from datetime import datetime

# %%
import openpyxl
# Load and concatenate all Excel files into a single DataFrame
dataframes = pd.DataFrame()
pattern = r'.*?(\d{8})[a-zA-Z]?_filtered\.csv'
for file in csv_files:
  match = re.search(pattern, file)
  if match:
      date_string= match.group(1)
      if len(date_string) == 8:
        try:
            # date_object = datetime.strptime(date_string, '%Y%m%d')
            # formatted_date = date_object.strftime('%Y-%m-%d')
            # print(f"File: {file_path}, Extracted Date: {formatted_date}")
          date_object = datetime.strptime(date_string, '%Y%m%d')
          formatted_date = date_object.strftime('%Y-%m-%d')
          df = pd.read_csv(file)
          df['date'] = formatted_date
          dataframes = pd.concat([dataframes, df], axis=0, ignore_index=True)
        except ValueError as e:
            print(f"Error processing {file}: {e}")

  else:
      continue
  # match = re.search(pattern, file)
  # if not match:
  #   continue
  # date_string = match.group(1)
# data = pd.concat(dataframes, ignore_index=True)
# dataframes = [pd.read_csv(file) for file in csv_files]
# data = pd.concat(dataframes, ignore_index=True)

# df = data.copy()
# Check the data
dataframes
# Out:
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/199710143_filtered.csv: unconverted data remains: 3
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200501072_filtered.csv: unconverted data remains: 2
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/199709122_filtered.csv: unconverted data remains: 2
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/199910282_filtered.csv: unconverted data remains: 2
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200410073_filtered.csv: time data '00410073' does not match format '%Y%m%d'
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200105212_filtered.csv: unconverted data remains: 2
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200404232_filtered.csv: unconverted data remains: 2
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200404012_filtered.csv: unconverted data remains: 2
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200410072_filtered.csv: time data '00410072' does not match format '%Y%m%d'
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200401033_filtered.csv: unconverted data remains: 3
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200503102_filtered.csv: unconverted data remains: 2
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200403252_filtered.csv: unconverted data remains: 2
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/199909082_filtered.csv: unconverted data remains: 2
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200511152_filtered.csv: unconverted data remains: 2
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200401042_filtered.csv: unconverted data remains: 2
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200012062_filtered.csv: unconverted data remains: 2
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200404222_filtered.csv: unconverted data remains: 2
# Error processing /content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/200010192_filtered.csv: unconverted data remains: 2
#        Unnamed: 0                                           sentence  \
# 0               0  Main Menu Toggle Button Sections Search Toggle...
# 1               1  Corporations Dealer Financing Terms Senior Cre...
# 2               2  May 26, 2021 The Economic Outlook and Monetary...
# 3               3  Today, I will explain why I expect the U.S. ec...
# 4               4  Households and businesses adapted, supported b...
# ...           ...                                                ...
# 11243          55  Or, the Committee could decide to maintain the...
# 11244          56  The Committee's normalization principles sugge...
# 11245          57  At that point, the amount of reserves will lik...
# 11246          58  With full employment within reach, signs of pr...
# 11247          59  These transitions in the economy and monetary ...
#
#              date
# 0      2021-05-26
# 1      2021-05-26
# 2      2021-05-26
# 3      2021-05-26
# 4      2021-05-26
# ...           ...
# 11243  2017-03-01
# 11244  2017-03-01
# 11245  2017-03-01
# 11246  2017-03-01
# 11247  2017-03-01
#
# [11248 rows x 3 columns]

# %%
dataframes.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
dataframes.to_csv('/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/combinedwithdates.csv', index=False)  # Update with the desired path

# %%
# Load the tokenizer
from transformers import RobertaTokenizer, RobertaForSequenceClassification, pipeline

tokenizer = RobertaTokenizer.from_pretrained("roberta-large")

# Load the fine-tuned models
model_hawk = RobertaForSequenceClassification.from_pretrained('/content/drive/MyDrive/NICHackathon/finetuned_roberta_large_Hawk')
model_stability = RobertaForSequenceClassification.from_pretrained('/content/drive/MyDrive/NICHackathon/finetuned_roberta_large_stability_')
model_trust = RobertaForSequenceClassification.from_pretrained('/content/drive/MyDrive/NICHackathon/finetuned_roberta_large_trust_')

# Create pipelines for each model
pipe_hawk = pipeline('text-classification', model=model_hawk, tokenizer=tokenizer, return_all_scores=True)
pipe_stability = pipeline('text-classification', model=model_stability, tokenizer=tokenizer, return_all_scores=True)
pipe_trust = pipeline('text-classification', model=model_trust, tokenizer=tokenizer, return_all_scores=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
# Function to classify a sentence with a given pipeline
def classify_sentence_hawk(pipeline, sentence):
    prompt = ("Discard all the previous instructions. Behave like you are an expert sentence classifier. "
              "Classify the following sentence from FOMC into 'NEUTRAL', 'HAWKISH', or 'DOVISH'. "
              "Label 'NEUTRAL' if the stance is clearly not neutral and the sentence has no effect, "
              "'HAWKISH' if it is corresponding to tightening of the monetary policy, or 'DOVISH' "
              "if it is corresponding to easing of the monetary policy. Provide the label in the first "
              "line and provide a short explanation in the second line. The sentence: " + sentence)

    result = pipeline(prompt)[0]
    # best_label = max(result, key=lambda x: x['score'])
    # label = best_label['label']
    # score = best_label['score']
    # return label, score
    label_map = {'LABEL_0': 'NEUTRAL', 'LABEL_1': 'HAWKISH', 'LABEL_2': 'DOVISH'}
    # Find the label with the highest score
    best_label = max(result, key=lambda x: x['score'])
    label = label_map[best_label['label']]
    score = best_label['score']
    return label, score
def classify_sentence_trust(pipeline, sentence):
    message = ("Discard all the previous instructions. Behave like you are an expert sentence classifier. Classify the following sentence from FOMC into 'TRUST', 'MISTRUST', or 'NEUTRAL' class. Label 'TRUST' if it the sentence has a positive effect on public trust of the FOMC, 'MISTRUST' if the sentence has a negative effect on public trust of the FOMC , or 'NEUTRAL' if the stance is neutral. Provide the label in the first line and provide a short explanation in the second line. The sentence: " + sentence)
    result = pipeline(message)[0]
    label_map = {'LABEL_0': 'TRUST', 'LABEL_1': 'MISTRUST', 'LABEL_2': 'NEUTRAL'}
    # Find the label with the highest score
    best_label = max(result, key=lambda x: x['score'])
    label = label_map[best_label['label']]
    score = best_label['score']
    return label, score
    # best_label = max(result, key=lambda x: x['score'])
    # label = best_label['label']
    # score = best_label['score']
    # return label, score
def classify_sentence_stability(pipeline, sentence):
    message = ("Discard all the previous instructions. Behave like you are an expert sentence classifier. Classify the following sentence from FOMC into 'STABLE', 'VOLATILE', 'NO-EFFECT'. Label 'STABLE' if the sentence has underlying implications of an incoming stable market, 'VOLATILE' if it implies uncertainty in the market is expected in the future, and 'NO-EFFECT' only if the sentence is a filler and sentence has no implications. Provide the label in the first line and provide a short explanation in the second line. The sentence: " + sentence)
    result = pipeline(message)[0]
    label_map = {'LABEL_0': 'STABLE', 'LABEL_1': 'VOLATILE', 'LABEL_2': 'NO-EFFECT'}
    # Find the label with the highest score
    best_label = max(result, key=lambda x: x['score'])
    label = label_map[best_label['label']]
    score = best_label['score']
    return label, score
    # best_label = max(result, key=lambda x: x['score'])
    # label = best_label['label']
    # score = best_label['score']
    # return label, score

# %%
input_df = pd.read_csv('/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/combinedwithdates.csv')  # Update with the correct path to your CSV file

# Prepare DataFrames to store results
results_hawk = []
results_stability = []
# results_trust = []

# Process the input DataFrame and save results every 1000 iterations
for idx, row in input_df.iterrows():
    if idx <5000:
        continue
    # print(idx)
    if idx > 0 and idx % 500 == 0:
        # Save the results to CSV files
        df_hawk = pd.DataFrame(results_hawk)
        df_stability = pd.DataFrame(results_stability)
        # df_trust = pd.DataFrame(results_trust)

        df_hawk.to_csv('/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/hawk_results2.csv', index=False)
        df_stability.to_csv('/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/stability_results2.csv', index=False)
        # df_trust.to_csv('/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/trust_results.csv', index=False)

        print(f"Saved results at iteration {idx}")

    sentence = row['sentence']
    date = row['date']

    try:
        label_hawk, score_hawk = classify_sentence_hawk(pipe_hawk, sentence)
        results_hawk.append({'sentence': sentence, 'date': date, 'label': label_hawk, 'score': score_hawk})
    except Exception as e:
        print(f"Error processing hawk at index {idx}: {e}")
        continue

    try:
        label_stability, score_stability = classify_sentence_stability(pipe_stability, sentence)
        results_stability.append({'sentence': sentence, 'date': date, 'label': label_stability, 'score': score_stability})
    except Exception as e:
        print(f"Error processing stability at index {idx}: {e}")
        continue

    # try:
    #     label_trust, score_trust = classify_sentence_trust(pipe_trust, sentence)
    #     results_trust.append({'sentence': sentence, 'date': date, 'label': label_trust, 'score': score_trust})
    # except Exception as e:
    #     print(f"Error processing trust at index {idx}: {e}")
    #     continue

# Save the final results to CSV files
df_hawk = pd.DataFrame(results_hawk)
df_stability = pd.DataFrame(results_stability)
# df_trust = pd.DataFrame(results_trust)

df_hawk.to_csv('/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/hawk_results_final2.csv', index=False)
df_stability.to_csv('/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/stability_results_final2.csv', index=False)
# df_trust.to_csv('/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/trust_results_final.csv', index=False)

print("Processing complete and final results saved.")


# # Load the input DataFrame
# input_df = pd.read_csv('/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/combinedwithdates.csv')  # Update with the correct path to your CSV file

# # Prepare DataFrames to store results
# results_hawk = []
# results_stability = []
# results_trust = []

# # Classify sentences using each model
# for idx, row in input_df.iterrows():
#     sentence = row['sentence']
#     date = row['date']

#     label_hawk, score_hawk = classify_sentence_hawk(pipe_hawk, sentence)
#     # print(label_hawk, score_hawk)
#     results_hawk.append({'sentence': sentence, 'date': date, 'label': label_hawk, 'score': score_hawk})

#     label_stability, score_stability = classify_sentence_stability(pipe_stability, sentence)
#     # print(label_stability, score_stability)
#     results_stability.append({'sentence': sentence, 'date': date, 'label': label_stability, 'score': score_stability})

#     label_trust, score_trust = classify_sentence_trust(pipe_trust, sentence)
#     # print(label_trust, score_trust)
#     results_trust.append({'sentence': sentence, 'date': date, 'label': label_trust, 'score': score_trust})

# # Create separate DataFrames for each model's results
# df_hawk = pd.DataFrame(results_hawk)
# df_stability = pd.DataFrame(results_stability)
# df_trust = pd.DataFrame(results_trust)

# # Save the results to CSV files
# df_hawk.to_csv('/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/hawk_results.csv', index=False)  # Update with the desired path
# df_stability.to_csv('/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/stability_results.csv', index=False)  # Update with the desired path
# df_trust.to_csv('/content/drive/MyDrive/NICHackathon/filtered_data/filtered_data/speech/select/trust_results.csv', index=False)  # Update with the desired path
# Out:
# Saved results at iteration 5000
# Error processing hawk at index 5048: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Error processing hawk at index 5149: The expanded size of the tensor (775) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 775].  Tensor sizes: [1, 514]
# Saved results at iteration 5500
# Error processing hawk at index 5578: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Error processing hawk at index 5866: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Saved results at iteration 6000
# Error processing hawk at index 6192: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Error processing hawk at index 6440: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Saved results at iteration 6500
# Saved results at iteration 7000
# Error processing hawk at index 7040: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Error processing hawk at index 7063: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Error processing hawk at index 7077: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Error processing hawk at index 7212: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Saved results at iteration 7500
# Saved results at iteration 8000
# Error processing hawk at index 8028: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Saved results at iteration 8500
# Error processing hawk at index 8649: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Error processing hawk at index 8676: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Saved results at iteration 9000
# Error processing hawk at index 9461: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Saved results at iteration 9500
# Error processing hawk at index 9593: The expanded size of the tensor (775) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 775].  Tensor sizes: [1, 514]
# Error processing hawk at index 9641: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Saved results at iteration 10000
# Error processing hawk at index 10121: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Saved results at iteration 10500
# Error processing hawk at index 10828: The expanded size of the tensor (777) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 514]
# Saved results at iteration 11000
# Processing complete and final results saved.
